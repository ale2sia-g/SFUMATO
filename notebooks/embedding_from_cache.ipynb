# %% [markdown]
# # Embedding representations
#
# This notebook runs the optional post-processing step from the shared pipeline config. Outputs are written into the matching `K*/SVD*/images/` folders.

# %%
# !python ../plot_embedding_umap.py --config ../configs/mousexeniumniche.json --k 30

# %%
# !python ../plot_embedding_dims.py --config ../configs/mousexeniumniche.json --k 30
