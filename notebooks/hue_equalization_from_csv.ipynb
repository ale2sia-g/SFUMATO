# %% [markdown]
# # Hue equalization figure
#
# This notebook reconstructs the circular hue rotation/equalization figure from a `hues_*.csv` file generated by `bgm_gpu_step_svd.py`.

# %%
from pathlib import Path

from plot_hue_equalization import plot_hue_equalization_from_csv

hues_csv = Path("../results_mousexeniumniche_svd/K30/SVD10/hues_mousexeniumniche_BGM45to30_BIN40_F8_SVD10.csv")
output_png = Path("../results_mousexeniumniche_svd/K30/SVD10/images/mousexeniumniche_K30_SVD10_hue_equalization.png")

plot_hue_equalization_from_csv(hues_csv, output_png)
output_png
