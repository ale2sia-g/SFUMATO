# %% [markdown]
# # UMAP representations
#
# This notebook runs the optional UMAP post-processing step from the shared pipeline config. Outputs are written into the matching `K*/SVD*/images/` folders.

# %%
# !python ../plot_embedding_umap.py --config ../configs/mousexeniumniche.json --k 30
